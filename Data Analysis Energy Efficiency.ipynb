# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from pandas import DataFrame,read_excel,merge
warnings.filterwarnings("ignore")
# %matplotlib inline #grafikleri görünür hale getirir.
# Out:
# UsageError: unrecognized arguments: #grafikleri görünür hale getirir.

# %%
dt= pd.read_csv(r"C:\Users\bkoca\Desktop\energyefficiency.csv")

# %%
dt.info
# Out:
# <bound method DataFrame.info of        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]>

# %%
dt.isnull().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %%
sns.set(style="dark",palette="bright", font_scale=1.5)
sns.distplot(dt["Y1"], color = "r")
plt.tight_layout()

# %%
sns.set(style="dark",palette="Blues", font_scale=1)
sns.distplot(dt["Y2"],hist=False,color = "m",kde_kws={"shade":True})
plt.tight_layout()

# %%
sns.set(style="dark",palette="bright", font_scale=1)
sns.distplot(dt["X1"],hist=False,color = "y",kde_kws={"shade":True})
plt.tight_layout()

# %%
sns.set(style="whitegrid",font_scale=1.5)

f,axes = plt.subplots(2,2,figsize=(15,10))

sns.distplot(dt["X1"],color = "r", ax= axes[0,0])
sns.distplot(dt["X2"],hist=False,color = "g",ax= axes[0,1])
sns.distplot(dt["X3"],hist=False,color = "m",kde_kws={"shade":True},ax= axes[1,0])
sns.distplot(dt["X4"],hist=False,color = "y",kde_kws={"shade":True},ax= axes[1,1])
# Out:
# <AxesSubplot:xlabel='X4', ylabel='Density'>

# %%
sns.jointplot(dt ["X5"],dt["Y1"],data=dt)

# %%
sns.jointplot(dt ["X5"],dt["Y1"],data=dt, kind="hex",color="r")

#yoğunlaşan yerleri koyu renk yapar.

# %%
sns.jointplot(dt["X5"],dt["Y1"],data=dt,kind="reg",color="r")

# %%
sns.jointplot(dt["X5"],dt["Y1"],data=dt,kind="kde",color="r")

# %%
sns.kdeplot(dt["X5"],dt["Y1"],shade=True,cmap="Blues")
# Out:
# <AxesSubplot:xlabel='X5', ylabel='Y1'>

# %%
sns.pairplot(dt,palette = "#95a5a6")

# %%
sns.boxplot(x="X5",y="Y1",data=dt,width=0.5)
plt.tight_layout()

# %%
sns.set(style="whitegrid")
sns.violinplot(x="X5",y="Y2",data=dt, palette ="PRGn")
# Out:
# <AxesSubplot:xlabel='X5', ylabel='Y2'>

# %%
sns.barplot(x="X5",y="Y2",data=dt,palette="Set1")
# Out:
# <AxesSubplot:xlabel='X5', ylabel='Y2'>

# %%
sns.stripplot(x="X5",y="Y1",data=dt,palette="Set1" )
# Out:
# <AxesSubplot:xlabel='X5', ylabel='Y1'>

# %%
sns.violinplot(x="X5",y="Y1",data=dt, palette ="PRGn")
sns.swarmplot(x="X5",y="Y1",data=dt,palette="Set1" )
# Out:
# <AxesSubplot:xlabel='X5', ylabel='Y1'>

# %%
corrmat = dt.corr()
corrmat
# Out:
#               X1            X2            X3            X4            X5  \
# X1  1.000000e+00 -9.919015e-01 -2.037817e-01 -8.688234e-01  8.277473e-01
# X2 -9.919015e-01  1.000000e+00  1.955016e-01  8.807195e-01 -8.581477e-01
# X3 -2.037817e-01  1.955016e-01  1.000000e+00 -2.923165e-01  2.809757e-01
# X4 -8.688234e-01  8.807195e-01 -2.923165e-01  1.000000e+00 -9.725122e-01
# X5  8.277473e-01 -8.581477e-01  2.809757e-01 -9.725122e-01  1.000000e+00
# X6  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# X7  1.283986e-17  1.318356e-16 -7.969726e-19 -1.381805e-16  1.861418e-18
# X8  1.764620e-17 -3.558613e-16  0.000000e+00 -1.079129e-16  0.000000e+00
# Y1  6.222719e-01 -6.581199e-01  4.556714e-01 -8.618281e-01  8.894305e-01
# Y2  6.343391e-01 -6.729989e-01  4.271170e-01 -8.625466e-01  8.957852e-01
#
#           X6            X7            X8        Y1        Y2
# X1  0.000000  1.283986e-17  1.764620e-17  0.622272  0.634339
# ...

# %%
dt.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2'], dtype='object')

# %%
fig , ax =plt.subplots(figsize=(56,56))
sns.heatmap (corrmat, annot = True, annot_kws= None)
# Out:
# <AxesSubplot:>
